# %%
import gym
import gym_fire
import numpy as np

# %%
env = gym.make('HellLake-v0')

# %%
env.reset()
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %% [raw]
# 0 : Left
# 1 : Down
# 2 : Right
# 3 : Up

# %%
env.P[5]
# Out:
# {0: [(1.0, 5, -0.01, True)],
#  1: [(1.0, 5, -0.01, True)],
#  2: [(1.0, 5, -0.01, True)],
#  3: [(1.0, 5, -0.01, True)]}

# %%
discount = .25

# %%
def iterate_value(env, discount=1.0, max_iters=10000, convergence=1e-20):
    
    # initialize reward value for each state
    V = np.zeros(env.observation_space.n)
    
    for i in range(max_iters):
        # for convergence comparison
        old_V = np.copy(V) 
        
        # calculate reward value for each state
        for state in range(env.observation_space.n):
            state_rewards = []
            for action in range(env.action_space.n):
                expected_rewards = []
                # calculate total expected reward for each action
                for next_state_action in env.P[state][action]: 
                    transition_p, next_state, reward_p, _ = next_state_action 
                    expected_rewards.append((transition_p * (reward_p + discount * V[next_state]))) 
                
                state_rewards.append(np.sum(expected_rewards))
            
            # update value table with reward for action with the best reward
            V[state] = max(state_rewards) 
            
        # check convergence
        if (np.sum(np.fabs(V - old_V)) <= convergence):
            print(f'Converged on iteration {i}')
            return(V)
    
    print(f'Did not converge in {i} iterations, returning last value table')
    return(V)

# %%
def get_policy(value_array, discount=1.0):
 
    # initialize policy
    policy = np.zeros(env.observation_space.n) 
    
    for state in range(env.observation_space.n):
        # initialize the rewards for a state
        V = np.zeros(env.action_space.n)
        
        # compute expected reward for all actions of state
        for action in range(env.action_space.n):
            for next_state_action in env.P[state][action]: 
                transition_p, next_state, reward_p, _ = next_state_action 
                V[action] += (transition_p * (reward_p + discount * value_array[next_state]))
        
        # select the action which has max reward as an optimal action of the state
        policy[state] = np.argmax(V)
    
    return policy

# %%
value_array =  iterate_value(env, discount=discount)
# Out:
# Converged on iteration 46

# %%
value_array
# Out:
# array([-3.90534022e-03, -1.46526362e-03, -3.44489854e-04, -4.87980211e-03,
#        -1.49347882e-03, -1.33333333e-02,  2.21118748e-03, -1.33333333e-02,
#        -6.83072291e-04,  6.62994466e-03,  4.02120730e-02, -1.33333333e-02,
#        -1.33333333e-02,  4.00303353e-02,  4.73703744e-01,  1.21052911e+00])

# %%
policy = get_policy(value_array, discount=discount)

# %%
policy
# Out:
# array([1., 1., 1., 0., 2., 0., 0., 0., 2., 1., 0., 0., 0., 2., 2., 1.])

# %%
def run_policy(env, policy):
    env.reset()
    env.render()
    reward = 0
    state = 0
    step = 0
    stuck = 0
    dead = False
    while (state != 15) & (reward > -1.5):
        next = env.step(int(policy[state]))
        dead = next[2]
        reward += next[1]
        state = next[0]
        step += 1
        if dead: 
            stuck += 1
        print(f'Step reward: {next[1]}')
        print(f'Cumulative reward: {reward}')
        env.render()

    if reward > 0:
        print(f'Gotem in {step} steps with reward {reward}')
    else:
        print(f'RIP in {step - stuck - 1} steps, Purgatorio for {stuck - 1} steps')

# %%
run_policy(env, policy)
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: 0.0
# Cumulative reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.01
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.02
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.03
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.04
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.05
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.060000000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.07
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.08
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.09
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.09999999999999999
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.10999999999999999
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.11999999999999998
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.12999999999999998
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.13999999999999999
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.15
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.16
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.17
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.18000000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.19000000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.20000000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.21000000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.22000000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.23000000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.24000000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.25000000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.26000000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.2700000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.2800000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.2900000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.3000000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.3100000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.3200000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.3300000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.34000000000000014
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.35000000000000014
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.36000000000000015
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.37000000000000016
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.38000000000000017
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.3900000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.4000000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.4100000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.4200000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.4300000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.4400000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.45000000000000023
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.46000000000000024
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.47000000000000025
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.48000000000000026
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.49000000000000027
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5000000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5100000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5200000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5300000000000002
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5400000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5500000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5600000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5700000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5800000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.5900000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6000000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6100000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6200000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6300000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6400000000000003
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6500000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6600000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6700000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6800000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.6900000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7000000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7100000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7200000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7300000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7400000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7500000000000004
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7600000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7700000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7800000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.7900000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8000000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8100000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8200000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8300000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8400000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8500000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8600000000000005
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8700000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8800000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.8900000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9000000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9100000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9200000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9300000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9400000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9500000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9600000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9700000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9800000000000006
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -0.9900000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0000000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0100000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0200000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0300000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0400000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0500000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0600000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0700000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0800000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.0900000000000007
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1000000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1100000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1200000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1300000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1400000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1500000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1600000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1700000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1800000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.1900000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2000000000000008
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2100000000000009
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2200000000000009
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2300000000000009
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2400000000000009
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.2500000000000009
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.260000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.270000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.280000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.290000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.300000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.310000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.320000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.330000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.340000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.350000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.360000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.370000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.380000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.390000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.400000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.410000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.420000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.430000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.440000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.450000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.460000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.470000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.480000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.490000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step reward: -0.01
# Cumulative reward: -1.500000000000001
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# RIP in 8 steps, Purgatorio for 150 steps

# %%
env.P[14]
# Out:
# {0: [(0.3333333333333333, 10, 0.0, False),
#   (0.3333333333333333, 13, 0.0, False),
#   (0.3333333333333333, 14, -0.001, False)],
#  1: [(0.3333333333333333, 13, 0.0, False),
#   (0.3333333333333333, 14, -0.001, False),
#   (0.3333333333333333, 15, 0.0, True)],
#  2: [(0.3333333333333333, 14, -0.001, False),
#   (0.3333333333333333, 15, 0.0, True),
#   (0.3333333333333333, 10, 0.0, False)],
#  3: [(0.3333333333333333, 15, 0.0, True),
#   (0.3333333333333333, 10, 0.0, False),
#   (0.3333333333333333, 13, 0.0, False)]}
